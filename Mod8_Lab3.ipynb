# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgagorrela/FMML_project_and_labs/blob/main/Mod8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-22 14:58:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   116MB/s    in 0.6s
#
# 2024-05-22 14:58:10 (116 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1972   1705.05884v1  In this report, an automated bartender system ...  stat
# 35576   0908.3091v2  For natural and artificial systems with some s...    cs
# 2768   1711.04528v1  Neural networks have recently had a lot of suc...  stat
# 20006   1312.5162v1  BP3TKI Palembang is the government agencies th...    cs
# 11572  1606.04460v1  State of the art deep reinforcement learning a...  stat
# ...             ...                                                ...   ...
# 34624  1706.10192v3  Neural IR models, such as DRMM and PACRR, have...    cs
# 6949   1708.00049v1  Active learning has long been a topic of study...  stat
# 22328  1602.02964v4  We propose a nonparametric statistical test fo...  stat
# 39602  1610.01732v4  Semantic segmentation of functional magnetic r...    cs
# 2524   1510.00878v2  We present a data mining approach for profilin...    cs
#
#                                                    title  year  \
# 1972        Static Gesture Recognition using Leap Motion  2017
# 35576  Computational Understanding and Manipulation o...  2009
# 2768   Simple And Efficient Architecture Search for C...  2017
# 20006  Sistem pendukung keputusan kelayakan TKI ke lu...  2013
# 11572                        Model-Free Episodic Control  2016
# ...                                                  ...   ...
# 34624  Co-PACRR: A Context-Aware Neural IR Model for ...  2017
# 6949                       Interpretable Active Learning  2017
# 22328                   A Kernel Test of Goodness of Fit  2016
# 39602  PCA-aided Fully Convolutional Networks for Sem...  2016
# 2524   Client Profiling for an Anti-Money Laundering ...  2015
#
#                                                 keywords
# 1972   [automated, bartender, developed, recognition,...
# 35576  [artificial, structure, computational, underst...
# 2768   [architectures, typically, cumbersome, automat...
# 20006  [palembang, government, coordinate, selection,...
# 11572  [reinforcement, algorithms, interactions, perf...
# ...                                                  ...
# 34624  [successfully, capturing, relevance, important...
# 6949   [increasingly, investigation, interpreting, ex...
# 22328  [nonparametric, statistical, determines, gener...
# 39602  [segmentation, functional, resonance, patholog...
# 2524   [profiling, detection, laundering, operations,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1972     [automated, bartender, developed, recognition,...
# 35576    [artificial, structure, computational, underst...
# 2768     [architectures, typically, cumbersome, automat...
# 20006    [palembang, government, coordinate, selection,...
# 11572    [reinforcement, algorithms, interactions, perf...
#                                ...
# 23791    [convolutional, requirement, artificial, recog...
# 11658    [universal, unanswered, neuroscience, computer...
# 13010    [generalize, minimizing, functions, functions,...
# 4241     [attributed, abundance, collecting, especially...
# 24622    [recognition, photographed, buildings, informa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8732 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d1a7366b-a84a-4a65-85a0-896afef3a469" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1a7366b-a84a-4a65-85a0-896afef3a469")) {                    Plotly.newPlot(                        "d1a7366b-a84a-4a65-85a0-896afef3a469",                        [{"x":["interaction","techniques","automated","initially","recognition","developed","collected","complement","permutation","algebraic","solutions","structural","symmetries","understanding","manipulation","artificial","computational","exploiting","structure","typically","architectures","performing","annealing","convolutional","surprisingly","cumbersome","procedure","magnitude","architecture","optimization","operators","efficient","requiring","resources","automatically","competitive","microsoft","procedures","implementation","guidelines","registration","selection","prospective","attribute","determine","development","government","necessary","coordinate","sequential","placement","employment","performance","investigate","interactions","rewarding","algorithms","environment","demonstrate","challenging","difficult","discovery","reinforcement","hippocampus","significantly","hippocampal","unbounded","versatility","complexity","evolution","predictions","increasing","environments","organisms","undermine","accelerating","empirical","adaptation","suggested","arguments","controversial","theoretical","evolutionary","biological","orientation","locations","experiments","inference","positions","comparable","localization","efficiency","segmentation","algorithm","regressing","classified","detection","suppressed","generated","candidate","categories","segmenting","shortcomings","processing","arbitrary","naturally","localizing","proximity","variation","outperforming","recommendation","versatile","overcomes","evaluation","filtering","incorporates","factorization","information","recommender","collaborative","completion","formulates","particularly","similarity","combination","underlying","implement","constrained","associated","continuity","distributions","computing","approximate","introduce","distribution","framework","approximated","truncated","hamiltonian","potential","functions","truncation","performed","differentiability","probability","therefore","traditional","modification","constructive","exponential","computationally","stochastic","surprising","improvement","knowledge","generalization","incorporate","practically","explicitly","furthermore","conditioned","collisions","uncertainty","variational","individual","differentiable","autoencoders","autoregressive","trajectory","generative","nonlinear","prediction","effectively","expressing","trajectories","researchers","conceived","supervised","anonymized","extraction","biomedical","relations","undertake","confidentiality","radiology","annotated","sensitivity","measurable","construct","including","universal","principal","simultaneously","hierarchical","industries","discriminative","technology","individuals","contributing","visualized"],"y":[79,372,104,23,358,195,65,22,11,14,142,63,5,163,21,130,290,77,345,87,121,63,7,368,31,4,130,63,258,315,64,446,48,60,181,111,10,43,127,14,29,160,3,44,69,129,5,86,35,87,7,4,907,136,66,1,577,111,571,272,161,57,119,3,242,1,9,6,241,56,90,115,97,7,1,13,153,59,21,28,6,158,74,44,19,53,611,192,23,95,54,171,208,810,2,41,342,3,172,53,76,21,16,278,87,61,12,9,79,36,36,9,11,258,71,34,39,722,20,43,28,3,95,147,149,122,67,62,117,5,103,131,100,348,226,550,17,5,4,174,213,2,128,1,165,151,158,24,3,43,115,129,8,162,346,121,65,11,67,155,23,7,91,48,136,18,17,7,26,117,59,250,121,10,26,72,7,195,1,127,19,103,2,2,4,75,40,1,102,238,35,32,112,102,3,117,56,42,7,2],"type":"bar"},{"x":["interaction","techniques","automated","initially","recognition"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8316666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Re</span> <span style=''>Weighted</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>Sparsifying</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.41025641025641035);'>addresses</span> <span style=''>the</span> <span style=''>topic</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>sparsifying</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNNs)</span> <span style=''>While</span> <span style=''>DNNs</span> <span style=''>are</span> <span style=''>powerful</span> <span style=''>models</span> <span style=''>that</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>the</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>poses</span> <span style=''>serious</span> <span style=''>storage</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3298969072164949);'>challenges</span> <span style=''>To</span> <span style=''>combat</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>difficulties</span> <span style=''>a</span> <span style=''>growing</span> <span style=''>line</span> <span style=''>of</span> <span style=''>work</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>pruning</span> <span style=''>network</span> <span style=''>weights</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.36);'>sacrificing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>affine</span> <span style=''>scaling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformation</span> <span style=''>(AST)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>sparsify</span> <span style=''>DNNs</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>follows</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>footsteps</span> <span style=''>of</span> <span style=''>popular</span> <span style=''>sparse</span> <span style=''>recovery</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>which</span> <span style=''>have</span> <span style=''>yet</span> <span style=''>to</span> <span style=''>be</span> <span style=''>explored</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>DNNs</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforming</span> <span style=''>densely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connected</span> <span style=''>DNNs</span> <span style=''>into</span> <span style=''>sparsely</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Communication</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constraints</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>studies</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>smooth</span> <span style=''>function</span> <span style=''>with</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>machines</span> <span style=''>We</span> <span style=''>assume</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>a</span> <span style=''>white</span> <span style=''>noise</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>at</span> <span style=''>each</span> <span style=''>machine</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>true</span> <span style=''>function</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>at</span> <span style=''>a</span> <span style=''>central</span> <span style=''>machine</span> <span style=''>We</span> <span style=''>place</span> <span style=''>limits</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>bits</span> <span style=''>that</span> <span style=''>each</span> <span style=''>machine</span> <span style=''>can</span> <span style=''>use</span> <span style=''>to</span> <span style=''>transmit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>to</span> <span style=''>the</span> <span style=''>central</span> <span style=''>machine</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>give</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>and</span> <span style=''>matching</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>risk</span> <span style=''>under</span> <span style=''>various</span> <span style=''>settings</span> <span style=''>We</span> <span style=''>identify</span> <span style=''>three</span> <span style=''>regimes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>among</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>machines</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>at</span> <span style=''>each</span> <span style=''>machine</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Solutions</span> <span style=''>for</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.641509433962264);'>covariance</span> <span style=''>matrix</span> <span style=''>we</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explained</span> <span style=''>by</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3796296296296297);'>combination</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.3514851485148515);'>variables</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>constraining</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nonzero</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3796296296296297);'>combination</span> <span style=''>This</span> <span style=''>is</span> <span style=''>known</span> <span style=''>as</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>has</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>array</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>engineering</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3142857142857142);'>formulate</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>semidefinite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>computes</span> <span style=''>a</span> <span style=''>full</span> <span style=''>set</span> <span style=''>of</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>for</span> <span style=''>all</span> <span style=''>target</span> <span style=''>numbers</span> <span style=''>of</span> <span style=''>non</span> <span style=''>zero</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>with</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>O(n3)</span> <span style=''>where</span> <span style=''>n</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3514851485148515);'>variables</span> <span style=''>We</span> <span style=''>then</span> <span style=''>use</span> <span style=''>the</span> <span style=''>same</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Techniques</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>data</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>graphs</span> <br/><br/><span style=''>A</span> <span style=''>natural</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>analyze</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>data</span> <span style=''>of</span> <span style=''>form</span> <span style=''>what</span> <span style=''>connects</span> <span style=''>to</span> <span style=''>what</span> <span style=''>when</span> <span style=''>is</span> <span style=''>to</span> <span style=''>create</span> <span style=''>a</span> <span style=''>time</span> <span style=''>series</span> <span style=''>(or</span> <span style=''>rather</span> <span style=''>a</span> <span style=''>sequence)</span> <span style=''>of</span> <span style=''>graphs</span> <span style=''>through</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discretization</span> <span style=''>(bandwidth</span> <span style=''>selection)</span> <span style=''>and</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discretization</span> <span style=''>(vertex</span> <span style=''>contraction)</span> <span style=''>Such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discretization</span> <span style=''>together</span> <span style=''>with</span> <span style=''>non</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>can</span> <span style=''>be</span> <span style=''>useful</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>of</span> <span style=''>graphs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>of</span> <span style=''>graphs</span> <span style=''>(as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>vertex</span> <span style=''>clustering)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>found</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroscience</span> <span style=''>and</span> <span style=''>in</span> <span style=''>social</span> <span style=''>network</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>it</span> <span style=''>can</span> <span style=''>also</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>enhance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>(ie</span> <span style=''>vertex</span> <span style=''>clustering)</span> <span style=''>by</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span style=''>on</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>labels</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>a</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12619978670458584)
# 	knowledge (0.12300035549235691)
# 	experimental (0.1393530039104159)
# 	segmentation (0.07394241023817988)
# 	architecture (0.0917170280838962)
# 	information (0.2566654816921436)
# 	detection (0.1215783860646996)
# 	different (0.2744400995378599)
# 	recognition (0.12726626377532882)
# 	convolutional (0.1308211873444721)
#
# Some Statistics words are:
# 	variables (0.1373930548565677)
# 	stochastic (0.14141922496225465)
# 	theoretical (0.15500754906894817)
# 	distribution (0.18067438349270257)
# 	algorithm (0.3925515853044791)
# 	estimation (0.1731253145445395)
# 	statistical (0.16758933064921994)
# 	dimensional (0.19174635128334172)
# 	regression (0.1816809260191243)
# 	inference (0.2108706592853548)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0603a24a-c6bf-4e44-b20d-291e0313bb6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0603a24a-c6bf-4e44-b20d-291e0313bb6e")) {                    Plotly.newPlot(                        "0603a24a-c6bf-4e44-b20d-291e0313bb6e",                        [{"x":["interaction","techniques","automated","initially","recognition","developed","collected","complement","permutation","algebraic","solutions","structural","symmetries","understanding","manipulation","artificial","computational","exploiting","structure","typically","architectures","performing","annealing","convolutional","surprisingly","cumbersome","procedure","magnitude","architecture","optimization","operators","efficient","requiring","resources","automatically","competitive","microsoft","procedures","implementation","guidelines","registration","selection","prospective","attribute","determine","development","government","necessary","coordinate","sequential","placement","employment","performance","investigate","interactions","rewarding","algorithms","environment","demonstrate","challenging","difficult","discovery","reinforcement","hippocampus","significantly","hippocampal","unbounded","versatility","complexity","evolution","predictions","increasing","environments","organisms","undermine","accelerating","empirical","adaptation","suggested","arguments","controversial","theoretical","evolutionary","biological","orientation","locations","experiments","inference","positions","comparable","localization","efficiency","segmentation","algorithm","regressing","classified","detection","suppressed","generated","candidate","categories","segmenting","shortcomings","processing","arbitrary","naturally","localizing","proximity","variation","outperforming","recommendation","versatile","overcomes","evaluation","filtering","incorporates","factorization","information","recommender","collaborative","completion","formulates","particularly","similarity","combination","underlying","implement","constrained","associated","continuity","distributions","computing","approximate","introduce","distribution","framework","approximated","truncated","hamiltonian","potential","functions","truncation","performed","differentiability","probability","therefore","traditional","modification","constructive","exponential","computationally","stochastic","surprising","improvement","knowledge","generalization","incorporate","practically","explicitly","furthermore","conditioned","collisions","uncertainty","variational","individual","differentiable","autoencoders","autoregressive","trajectory","generative","nonlinear","prediction","effectively","expressing","trajectories","researchers","conceived","supervised","anonymized","extraction","biomedical","relations","undertake","confidentiality","radiology","annotated","sensitivity","measurable","construct","including","universal","principal","simultaneously","hierarchical","industries","discriminative","technology","individuals","contributing","visualized","independent","functional","applications","resonance","successfully","activities","successful","transferability","cognition","scientists","analogical","relational","representations","influential","scientific","analogies","cognitive","requirement","limitation","alternative","approaches","confident","available","confidence","classifier","specifically","consistently","contextual","expression","facilitated","conditioning","outperforms","processes","probabilistic","combining","classifiers","classification","retrieving","dimensionality","compressed","retrieval","projections","capabilities","comparative","histogram","integration","containing","classifying","gradients","benchmarked","conducted","perceptron","distributed","multilay ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bernstein
# 	repulsive
# 	interventional
# 	embarrassingly
# 	contiguous
# 	psychiatric
# 	irreducible
# 	reparametrization
# 	reparametrizations
# 	blockwise
# 	adversely
# 	unfairness
# 	counterfactuals
# 	individualized
# 	changepoints
# 	changepoint
# 	interpolate
# 	statisticians
# 	encrypted
# 	homomorphic
# Some words which never appear in Statistics papers:
# 	suppressed
# 	localizing
# 	conceived
# 	undertake
# 	analogical
# 	analogies
# 	benchmarked
# 	researched
# 	luminance
# 	segregation
# 	biasvariance
# 	participate
# 	breakthroughs
# 	strengthens
# 	tournaments
# 	irrespective
# 	correspondences
# 	assistant
# 	navigation
# 	ontological

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.058384561274735e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7783333333333333
