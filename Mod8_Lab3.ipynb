# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgagorrela/FMML_project_and_labs/blob/main/Mod8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 08:04:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  62.5MB/s    in 1.1s
#
# 2024-04-02 08:04:58 (62.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5160    1011.3090v2  Multiple kernel learning (MKL), structured spa...  stat
# 31337  1803.00401v1  Deep neural network (DNN) architecture based m...    cs
# 23058  1802.09656v1  Latent variable models with hidden binary unit...  stat
# 21950  1612.09297v1  We propose communication-efficient distributed...  stat
# 36771   1410.5614v1  This work aims to resolve issues related to We...    cs
# ...             ...                                                ...   ...
# 5757    1206.3881v1  In the last decades the estimation of the intr...    cs
# 14196  1803.03688v1  We show that, during inference with Convolutio...    cs
# 22170  1506.04158v3  This paper presents a novel spectral algorithm...  stat
# 21769   1303.6938v1  We propose a novel approach for nonlinear regr...  stat
# 21509   0805.1390v1  A simple and computationally efficient scheme ...  stat
#
#                                                    title  year  \
# 5160   Regularization Strategies and Empirical Bayesi...  2010
# 31337  Unravelling Robustness of Deep Learning based ...  2018
# 23058  Learning Binary Latent Variable Models: A Tens...  2018
# 21950  Communication-efficient Distributed Estimation...  2016
# 36771  The Tomaco Hybrid Matching Framework for SAWSD...  2014
# ...                                                  ...   ...
# 5757   DANCo: Dimensionality from Angle and Norm Conc...  2012
# 14196  Bit-Tactical: Exploiting Ineffectual Computati...  2018
# 22170  A Spectral Algorithm with Additive Clustering ...  2015
# 21769  Expectation Propagation for Neural Networks wi...  2013
# 21509    Random projection trees for vector quantization  2008
#
#                                                 keywords
# 5160   [structured, considerable, attention, differen...
# 31337  [architecture, expressive, essentially, mathem...
# 23058  [applications, particular, challenging, comput...
# 21950  [communication, efficient, distributed, estima...
# 36771  [retrieval, selection, discovery, essentially,...
# ...                                                  ...
# 5757   [estimation, intrinsic, dimensionality, consid...
# 14196  [inference, convolutional, ineffectual, target...
# 22170  [algorithm, clustering, overlapping, communiti...
# 21769  [nonlinear, regression, structure, hierarchica...
# 21509  [computationally, efficient, structured, quant...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5160     [structured, considerable, attention, differen...
# 31337    [architecture, expressive, essentially, mathem...
# 23058    [applications, particular, challenging, comput...
# 21950    [communication, efficient, distributed, estima...
# 36771    [retrieval, selection, discovery, essentially,...
#                                ...
# 22527    [stochastic, algorithm, statistical, estimatio...
# 7415     [stochastic, component, efficiency, theoretica...
# 31069    [computing, neuromorphic, computing, classific...
# 31184    [photography, restoration, extensively, indepe...
# 9752     [epidemiology, potential, understanding, frame...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8784 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9d72a463-a943-4318-b0e1-51c1301f855a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d72a463-a943-4318-b0e1-51c1301f855a")) {                    Plotly.newPlot(                        "9d72a463-a943-4318-b0e1-51c1301f855a",                        [{"x":["probabilistic","understood","empirical","components","structured","experiments","maximization","simplicity","operation","usefulness","generative","combination","different","comparable","applications","separable","regularizer","particular","information","systematically","attention","algorithms","numerical","naturally","regularization","conjugate","preferable","represented","considerable","strategies","likelihood","robustness","countermeasures","formulate","architectures","corrections","databases","essentially","assessing","effective","recognition","evaluation","characterizing","processing","adversaries","drawbacks","available","researchers","alleviate","including","distortions","adversarial","mathematically","designing","questioning","vulnerabilities","detecting","functions","performance","realizing","classifier","demonstrates","expressive","representation","detection","architecture","experimental","degeneracy","simulated","population","independent","orthogonal","consistently","parameters","exclusive","demonstrate","computational","statistically","challenging","generalizes","consistency","illustrate","eigenvectors","approaches","conditions","estimates","parametric","decomposition","transelliptical","centralized","estimators","statistical","satisfies","estimation","aggregates","thresholding","extension","distribution","dimensional","communication","graphical","efficient","elliptical","precision","estimator","distributes","averaging","generated","semiparametric","inference","synthetic","aggregated","distributed","algorithm","objective","introduces","application","discovery","syntactic","selection","configurable","introduced","similarity","technologies","accelerate","targeting","directions","descriptions","ontologies","annotations","especially","environment","framework","reproducible","integrates","combining","developed","collections","retrieval","contributed","aggregating","benchmark","establish","accuracies","discriminative","emphasizes","distribute","automatically","classifiers","classification","generalization","consistent","unsampled","bootstrap","repository","mechanism","aggregation","replacement","complexity","validation","preliminary","motivation","utilizing","computationally","analytically","sufficient","reduction","iteratively","component","favorably","dimension","predicting","performing","supervised","dependence","dimensionality","preserving","modalities","alternative","computing","orderless","advantage","resolution","strategically","challenge","forgetting","intrinsic","proximity","behaviour","comparison","weighting","potential","consumers","incorporated","forecasting","isomorphic","suggested","dimensions","originally","subsequently"],"y":[143,22,159,112,116,600,33,23,48,26,123,150,732,97,432,7,24,275,728,14,182,595,75,54,75,5,5,78,46,100,63,99,5,59,115,5,61,26,17,268,364,276,21,293,5,30,275,83,31,259,17,109,20,47,4,4,73,207,881,6,166,53,31,353,340,271,386,1,51,55,141,20,25,217,6,581,296,23,262,29,64,75,5,452,133,70,41,62,0,7,14,152,14,197,8,15,71,198,172,52,54,403,0,98,26,3,23,172,1,198,147,13,105,801,159,78,267,41,51,168,4,123,151,29,22,12,36,34,19,60,107,119,560,5,27,112,182,14,100,4,13,226,36,27,101,7,4,179,123,546,90,86,1,7,8,94,27,6,225,59,47,21,37,67,6,62,88,35,108,23,60,97,85,210,23,32,55,31,89,142,3,84,110,4,170,8,42,10,48,128,20,180,3,28,29,2,27,39,13,31],"type":"bar"},{"x":["probabilistic","understood","empirical","components","structured","experime ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style=''>Modified</span> <span style=''>Policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Iteration</span> <br/><br/><span style=''>Modified</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>(MPI)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3253012048192771);'>programming</span> <span style=''>(DP)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>contains</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>celebrated</span> <span style=''>policy</span> <span style=''>and</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>methods</span> <span style=''>Despite</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generality</span> <span style=''>MPI</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thoroughly</span> <span style=''>studied</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>form</span> <span style=''>which</span> <span style=''>is</span> <span style=''>used</span> <span style=''>when</span> <span style=''>the</span> <span style=''>state</span> <span style=''>andor</span> <span style=''>action</span> <span style=''>spaces</span> <span style=''>are</span> <span style=''>large</span> <span style=''>or</span> <span style=''>infinite</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>MPI</span> <span style=''>(AMPI)</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>of</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>DP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>fitted</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>fitted</span> <span style=''>Q</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>based</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>analyses</span> <span style=''>that</span> <span style=''>unify</span> <span style=''>those</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>policy</span> <span style=''>and</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>On</span> <span style=''>the</span> <span style=''>last</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3170731707317073);'>implementation</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Components</span> <span style=''>Analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extracting</span> <span style=''>Reliable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensions</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Data</span> <br/><br/><span style=''>How</span> <span style=''>does</span> <span style=''>one</span> <span style=''>find</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>reliably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>across</span> <span style=''>repetitions</span> <span style=''>For</span> <span style=''>example</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroscience</span> <span style=''>one</span> <span style=''>may</span> <span style=''>want</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>signals</span> <span style=''>that</span> <span style=''>are</span> <span style=''>reliably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activated</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>trials</span> <span style=''>or</span> <span style=''>subjects</span> <span style=''>For</span> <span style=''>a</span> <span style=''>clinical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessment</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>ratings</span> <span style=''>one</span> <span style=''>may</span> <span style=''>want</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregate</span> <span style=''>score</span> <span style=''>that</span> <span style=''>is</span> <span style=''>reliably</span> <span style=''>reproduced</span> <span style=''>across</span> <span style=''>raters</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>proposed</span> <span style=''>here</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlate</span> <span style=''>between</span> <span style=''>repetitions</span> <span style=''>(eg</span> <span style=''>trials</span> <span style=''>subjects</span> <span style=''>raters)</span> <span style=''>This</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ratio</span> <span style=''>of</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>repetition</span> <span style=''>to</span> <span style=''>within</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>repetition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style='background-color:r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.39364303178484117);'>stochastic</span> <span style=''>branch</span> <span style=''>and</span> <span style=''>bound</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>belief</span> <span style=''>tree</span> <span style=''>search</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.4505494505494505);'>reinforcement</span> <span style=''>learning</span> <br/><br/><span style=''>There</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4505494505494505);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exhibiting</span> <span style=''>near</span> <span style=''>optimal</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>The</span> <span style=''>main</span> <span style=''>obstacle</span> <span style=''>facing</span> <span style=''>such</span> <span style=''>methods</span> <span style=''>is</span> <span style=''>that</span> <span style=''>in</span> <span style=''>most</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>involves</span> <span style=''>planning</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>infinitely</span> <span style=''>large</span> <span style=''>tree</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(255, 0, 0, 0.39364303178484117);'>stochastic</span> <span style=''>lower</span> <span style=''>and</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>value</span> <span style=''>of</span> <span style=''>each</span> <span style=''>tree</span> <span style=''>node</span> <span style=''>This</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.39364303178484117);'>stochastic</span> <span style=''>branch</span> <span style=''>and</span> <span style=''>bound</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>search</span> <span style=''>the</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>two</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>examines</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>in</span> <span style=''>this</span> <span style=''>setting</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discriminated</span> <span style=''>Hub</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Lasso</span> <br/><br/><span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discriminated</span> <span style=''>Hub</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Lasso</span> <span style=''>(DHGL)</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Hub</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Lasso</span> <span style=''>(HGL)</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>of</span> <span style=''>hubs</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>this</span> <span style=''>new</span> <span style=''>method</span> <span style=''>in</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>with</span> <span style=''>known</span> <span style=''>hubs</span> <span style=''>and</span> <span style=''>without</span> <span style=''>known</span> <span style=''>hubs</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>compare</span> <span style=''>DHGL</span> <span style=''>with</span> <span style=''>HGL</span> <span style=''>using</span> <span style=''>several</span> <span style=''>measures</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>When</span> <span style=''>some</span> <span style=''>hubs</span> <span style=''>are</span> <span style=''>known</span> <span style=''>we</span> <span style=''>can</span> <span style=''>always</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style=''>better</span> <span style=''>via</span> <span style=''>DHGL</span> <span style=''>than</span> <span style=''>HGL</span> <span style=''>When</span> <span style=''>no</span> <span style=''>hubs</span> <span style=''>are</span> <span style=''>known</span> <span style=''>we</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Lasso</span> <span style=''>(GL)</span> <span style=''>to</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>of</span> <span style=''>hubs</span> <span style=''>and</span> <span style=''>find</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>DHGL</span> <span style=''>will</span> <span style=''>always</span> <span style=''>be</span> <span style=''>better</span> <span style=''>than</span> <span style=''>HGL</span> <span style=''>if</span> <span style=''>correct</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>given</span> <span style=''>and</span> <span style=''>will</span> <span style=''>seldom</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>degenerate</span> <span style=''>when</span> <span style=''>the</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>wrong</span> <br/><br/ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12634216177523264)
# 	knowledge (0.13027916964924838)
# 	segmentation (0.07086614173228346)
# 	experimental (0.1381531853972799)
# 	detection (0.12168933428775948)
# 	architecture (0.09699355762347889)
# 	information (0.26055833929849676)
# 	different (0.2619899785254116)
# 	recognition (0.13027916964924838)
# 	convolutional (0.14495347172512527)
#
# Some Statistics words are:
# 	estimation (0.1669990029910269)
# 	variables (0.13958125623130607)
# 	stochastic (0.14207377866400797)
# 	statistical (0.15453639082751744)
# 	theoretical (0.15553339980059822)
# 	algorithm (0.39930209371884345)
# 	distribution (0.19192422731804587)
# 	dimensional (0.18594217347956132)
# 	regression (0.17248255234297108)
# 	inference (0.2008973080757727)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="910f9d31-c3f6-4f09-9567-b1a2e13f0916" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("910f9d31-c3f6-4f09-9567-b1a2e13f0916")) {                    Plotly.newPlot(                        "910f9d31-c3f6-4f09-9567-b1a2e13f0916",                        [{"x":["probabilistic","understood","empirical","components","structured","experiments","maximization","simplicity","operation","usefulness","generative","combination","different","comparable","applications","separable","regularizer","particular","information","systematically","attention","algorithms","numerical","naturally","regularization","conjugate","preferable","represented","considerable","strategies","likelihood","robustness","countermeasures","formulate","architectures","corrections","databases","essentially","assessing","effective","recognition","evaluation","characterizing","processing","adversaries","drawbacks","available","researchers","alleviate","including","distortions","adversarial","mathematically","designing","questioning","vulnerabilities","detecting","functions","performance","realizing","classifier","demonstrates","expressive","representation","detection","architecture","experimental","degeneracy","simulated","population","independent","orthogonal","consistently","parameters","exclusive","demonstrate","computational","statistically","challenging","generalizes","consistency","illustrate","eigenvectors","approaches","conditions","estimates","parametric","decomposition","transelliptical","centralized","estimators","statistical","satisfies","estimation","aggregates","thresholding","extension","distribution","dimensional","communication","graphical","efficient","elliptical","precision","estimator","distributes","averaging","generated","semiparametric","inference","synthetic","aggregated","distributed","algorithm","objective","introduces","application","discovery","syntactic","selection","configurable","introduced","similarity","technologies","accelerate","targeting","directions","descriptions","ontologies","annotations","especially","environment","framework","reproducible","integrates","combining","developed","collections","retrieval","contributed","aggregating","benchmark","establish","accuracies","discriminative","emphasizes","distribute","automatically","classifiers","classification","generalization","consistent","unsampled","bootstrap","repository","mechanism","aggregation","replacement","complexity","validation","preliminary","motivation","utilizing","computationally","analytically","sufficient","reduction","iteratively","component","favorably","dimension","predicting","performing","supervised","dependence","dimensionality","preserving","modalities","alternative","computing","orderless","advantage","resolution","strategically","challenge","forgetting","intrinsic","proximity","behaviour","comparison","weighting","potential","consumers","incorporated","forecasting","isomorphic","suggested","dimensions","originally","subsequently","multiplying","conclusion","isomorphism","supervisor","resulting","prospects","investigate","universal","alternating","sequences","generator","convolutional","continuous","propagation","computations","parametrized","inferential","incomplete","following","realistic","optimized","enhancement","investigation","eventually","autonomous","eliminating","tremendously","introducing","advancement","outstanding","navigation","techniques","successful","environmental","increasing","conducted","inaccurate","comparative","capabilities","embeddings","representations","particularly","associations","extensively","production","psychology","frequency","pronounced","simulation","phenomenon","approximation","decreasing","unlabeled","automatic","surveil ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	transelliptical
# 	elliptical
# 	boundedness
# 	blockmodel
# 	embarrassingly
# 	tightness
# 	effectivity
# 	fragility
# 	byzantine
# 	parameterizes
# 	modulating
# 	distilling
# 	uncontaminated
# 	stabilisation
# 	depressive
# 	prospective
# 	scrambled
# 	consonants
# 	instruments
# 	resistant
# Some words which never appear in Statistics papers:
# 	countermeasures
# 	vulnerabilities
# 	syntactic
# 	configurable
# 	contributed
# 	emphasizes
# 	orderless
# 	strategically
# 	advancement
# 	linguistically
# 	perceptually
# 	associating
# 	suppression
# 	perceptive
# 	satisfiable
# 	smarandache
# 	enrichments
# 	logically
# 	conferences
# 	femtocell

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077112437688473e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
